# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# **CARREGA OS DADOS**

# %%
dataset = pd.read_csv('C:/Users/user/Documents/JOAO/python/projeto insight/kc_house_data.csv')

# %% [markdown]
# **PRÉ-PROCESSAMENTO**
#
# **LIMPEZA DE ALGUNS DADOS QUE NÃO É DE INTERESSE PARA ANÁLISE**

# %%
dataset2 = dataset.copy()
dataset2 = dataset2.drop(dataset2[['id','date','lat','long','zipcode','sqft_living15','sqft_lot15','grade']],axis=1)
dataset2.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated
# 0     0          3        1180              0      1955             0
# 1     0          3        2170            400      1951          1991
# 2     0          3         770              0      1933             0
# 3     0          5        1050            910      1965             0
# 4     0          3        1680              0      1987             0

# %% [markdown]
# **FAÇO O PRÉ-PROCESSAMENTO DE ALGUMAS FEATURES PARA OTIMIZAR O MODELO DE INSIGHT: IDETIFICANDO OS IMÓVEIS QUE FORAM REFORMADO OU NÃO E TRANSFORMANDO AS DATA DE CONSTRUÇÃO EM ANOS DE CONSTRUÍDO LEVANDO COMO BASE O ANO DE 2020.**

# %%
for i in range(21613):
    dataset2['yr_renovated'] = dataset2['yr_renovated'].loc[dataset2['yr_renovated']>0].replace(i,1)
dataset2['yr_renovated'] = dataset2['yr_renovated'].fillna(0)
dataset2.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated
# 0     0          3        1180              0      1955           0.0
# 1     0          3        2170            400      1951           1.0
# 2     0          3         770              0      1933           0.0
# 3     0          5        1050            910      1965           0.0
# 4     0          3        1680              0      1987           0.0

# %%
dataset2['yr_built'] = 2020 - dataset2['yr_built']
dataset2.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated
# 0     0          3        1180              0        65           0.0
# 1     0          3        2170            400        69           1.0
# 2     0          3         770              0        87           0.0
# 3     0          5        1050            910        55           0.0
# 4     0          3        1680              0        33           0.0

# %% [markdown]
# **FAÇO A MÉDIA DE TODOS OS VALORES DE METRO QUADRADO DOS IMÓVEIS QUE ANTES ESTAVA DIVIDIDO EM VALOR DO METRO QUADRADO DO LOTE, PORÃO, PRIMEIRO ANDAR E ETC. PARA ASSIM TER SOMENTE UM VALOR MÉDIO REFERÊNCIA PARA ANALÍSE DOS IMÓVEIS.**

# %%
mq1 = (dataset['sqft_living']+dataset['sqft_lot']+dataset['sqft_above']+dataset['sqft_basement'])/4
mq2=pd.DataFrame(mq1)
mq = np.array(mq2)
mq
# Out:
# array([[2002.5],
#        [3095.5],
#        [2885. ],
#        ...,
#        [ 847.5],
#        [1397. ],
#        [ 779. ]])

# %%
valor = dataset2[['price']].values
valor
# Out:
# array([[221900.],
#        [538000.],
#        [180000.],
#        ...,
#        [402101.],
#        [400000.],
#        [325000.]])

# %%
x= np.concatenate((valor,mq), axis = 1)
x
# Out:
# array([[221900. ,   2002.5],
#        [538000. ,   3095.5],
#        [180000. ,   2885. ],
#        ...,
#        [402101. ,    847.5],
#        [400000. ,   1397. ],
#        [325000. ,    779. ]])

# %% [markdown]
# **ANÁLISE EXPLORATÓRIA**
#
# **APLIQUEI UM CLUSTER K-MEANS PARA IDENTIFICAR PADRÕES RELACIONADOS AO VALOR DO IMÓVEL E O VALOR DO METRO QUADRADO MÉDIO DE CADA IMÓVEL, PARA ASSIM IDENTIFICAR PADRÕES QUE INTERESSEM SUAS OBTENÇÕES E QUE FUTURAMENTE TRAGA LUCRO PARA A EMPRESA. POIS QUANTO MENOR O VALOR DO IMÓVEL E MAIOR O VALOR DO METRO QUADRADO MAIS VANTAJOSO SERÁ A OBTENÇÃO DO MESMO.**

# %% [markdown]
# **CLUSTER K-MEANS - MÉTODO DE ELBOW PARA IDENTIFICAR QUANTIDADE DE PADRÕES**

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(x)

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(x[y_kmeans == 3, 0], x[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(x[y_kmeans == 4, 0], x[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Valor do Imovel')
plt.ylabel('Metro Quadrado')
plt.legend()
plt.show()

# %% [markdown]
# **COM BASE NESSA ANÁLISE É POSSÍVEL PERCEBER QUE OS IMÓVEIS DO AGRUPAMENTO 1,2 e 5 SÃO OS MAIS VANTAJOSO PARA A EMPRESA ATÉ AGORA, PRINCIPALMENTE OS QUE SÃO DESSE GRUPO E AINDA TEM O VALOR DO METRO QUADRADO ALTO, POIS SÃO IMÓVEIS COM BAIXO VALOR PORÉM COM UM ALTO VALOR DO METRO QUADRADO LOGO SÃO OTIMOS IMÓVEIS PARA REVENDER E TIRAR UM BOM LUCRO EM COMPARAÇÃO AOS OUTROS.**
#
# **PORÉM QUERO FILTRAR AINDA MAIS DE FORMA A ENCONTRAR QUAL AGRUPAMENTO É MAIS VANTAJOSO E EM QUAL ORDEM. SEGUINDO ANÁLISE ABAIXO CRIEI CRITÉRIOS.**

# %%
dataset2 = dataset2[['price','bedrooms','bathrooms','floors','waterfront','view','condition','yr_built','yr_renovated']]
df1 = dataset2.values
dfpr1=pd.DataFrame(y_kmeans)
dfpr = np.array(dfpr1)
df = np.concatenate((df1,mq,dfpr), axis = 1)

# %%
dftrr= pd.DataFrame(df)
dfinal = dftrr.rename({0:'Valor',1:'Quartos',2:'Banheiros',3:'Andares',4:'Aguafrente',5:'vista',6:'Condições',7:'Tempoconstruido',8:'Reformado',9:'v_med_mquad',10:'Padrões'}, axis=1)
dfinal.head()
# Out:
#       Valor  Quartos  Banheiros  Andares  Aguafrente  vista  Condições  \
# 0  221900.0      3.0       1.00      1.0         0.0    0.0        3.0
# 1  538000.0      3.0       2.25      2.0         0.0    0.0        3.0
# 2  180000.0      2.0       1.00      1.0         0.0    0.0        3.0
# 3  604000.0      4.0       3.00      1.0         0.0    0.0        5.0
# 4  510000.0      3.0       2.00      1.0         0.0    0.0        3.0
#
#    Tempoconstruido  Reformado  v_med_mquad  Padrões
# 0             65.0        0.0       2002.5      2.0
# 1             69.0        1.0       3095.5      4.0
# 2             87.0        0.0       2885.0      2.0
# 3             55.0        0.0       2230.0      4.0
# 4             33.0        0.0       2860.0      4.0

# %% [markdown]
# **ABAIXO FIZ UMA ANÁLISE PARA ESCOLHA DOS MELHORES IMÓVEIS, FIZ UM SISTEMA DE PONTUAÇÃO ONDE QUEM TIVER MENOR VALOR DE IMÓVEL TERÁ 5 PONTOS E DECRESCENDO DE ACORDO COM A ORDEM DOS CLUSTERS EX: O QUE TEM MENOR VALOR DE IMÓVEL LEVA 5 PTS, O SEGUNDO MENOR LEVA 4 PTS E ASSIM VAI.
#     JÁ PARA O METRO QUADRADO FOI O INVERSO, O QUE TIVER MAIOR VALOR DE METRO QUADRADO LEVA A MAIOR PONTUAÇÃO E RESPECTIVAMENTE POR TODOS OS CLUSTER.
#     LOGO COM ISSO ESTABELECI 2 CRITÉRIOS O DE MENOR VALOR E O DE MAIOR VALOR DE METRO QUADRADO ONDE O CLUSTER QUE TIVER MAIOR PONTUAÇÃO COM A SOMA DOS CRITÉRIOS SERÁ O MAIS VANTAJOSO, POIS EM COMPARAÇÃO AOS OUTROS TERÁ OS MENORES VALORES PARA COMPRA E MAIOR VALOR DE METRO QUADRADO LOGO SENDO UMA ÓTIMA OPORTUNIDADE DE REVENDA E OBTENÇÃO DE LUCRO.**

# %%
dem1= dfinal.loc[dfinal['Padrões']==0]
c1=np.array(dem1[['Valor','v_med_mquad']].mean())

# %%
dem2 = dfinal.loc[dfinal['Padrões']==1]
c2=np.array(dem2[['Valor','v_med_mquad']].mean())

# %%
dem3 = dfinal.loc[dfinal['Padrões']==2]
c3=np.array(dem3[['Valor','v_med_mquad']].mean())

# %%
dem4 = dfinal.loc[dfinal['Padrões']==3]
c4 = np.array(dem4[['Valor','v_med_mquad']].mean())

# %%
dem5 = dfinal.loc[dfinal['Padrões']==4]
c5 =np.array(dem5[['Valor','v_med_mquad']].mean())

# %% [markdown]
# **ANÁLISE DE CRITÉRIOS**
#
# **LINHA 0 = MEDIA DO VALOR DO IMÓVEL**
#
# **LINHA 1 = MEDIA DO METRO QUADRADO**

# %%
analis=pd.DataFrame({'cluster1':c1,'cluster2':c2,'cluster3':c3,'cluster4':c4,'cluster5':c5})
analis
# Out:
#         cluster1      cluster2       cluster3      cluster4       cluster5
# 0  825622.171720  1.457316e+06  296979.369232  2.855597e+06  522515.586773
# 1    6726.960156  7.934022e+03    3584.653204  7.886222e+03    4891.311353

# %% [markdown]
# **APLICANDO PONTUAÇÃO DOS CRITÉRIOS**

# %%
criterios=pd.DataFrame({'cluster1':[3,3,6],'cluster2':[2,5,7],'cluster3':[5,1,6],'cluster4':[1,4,5],'cluster5':[4,2,6]})
criterios
# Out:
#    cluster1  cluster2  cluster3  cluster4  cluster5
# 0         3         2         5         1         4
# 1         3         5         1         4         2
# 2         6         7         6         5         6

# %% [markdown]
# **COM BASE NA TABELA  ACIMA PODE SER OBSERVADO QUE OS IMÓVEIS DO AGRUPAMENTO 2 SÃO MAIS VANTAJOSOS, E EM SEGUIDA DELE OS PRÓXIMOS SÃO OS AGRUPAMENTOS 1,5,3,4.**
#
# **E APARTIR DESSA CONCLUSÃO SE FOR DE INTERESSE VOCÊ TAMBÉM PODE VOLTAR AO GRÁFICO DO CLUSTER E VALIDAR MAIS UMA VEZ A ESCOLHA, OBSERVANDO QUE OS CRITÉRIOS DE PONTUAÇÃO SÃO COERENTES E PRECISOS.**

# %%
dem2
# Out:
#            Valor  Quartos  Banheiros  Andares  Aguafrente  vista  Condições  \
# 5      1225000.0      4.0       4.50      1.0         0.0    0.0        3.0
# 21     2000000.0      3.0       2.75      1.0         0.0    4.0        3.0
# 49     1350000.0      3.0       2.50      1.0         1.0    2.0        5.0
# 69     1325000.0      5.0       2.25      1.0         0.0    0.0        3.0
# 125    1450000.0      4.0       2.75      1.5         0.0    0.0        3.0
# ...          ...      ...        ...      ...         ...    ...        ...
# 21551  1375000.0      5.0       4.50      2.0         0.0    0.0        3.0
# 21568  1700000.0      4.0       3.50      2.0         0.0    0.0        3.0
# 21590  1222500.0      4.0       3.50      1.5         0.0    0.0        3.0
# 21597  1575000.0      4.0       3.25      2.0         0.0    0.0        3.0
# 21600  1537000.0      5.0       3.75      2.0         0.0    0.0        3.0
#
#        Tempoconstruido  Reformado  v_med_mquad  Padrões
# 5                 19.0        0.0     28192.50      1.0
# 21                52.0        0.0     12741.75      1.0
# 49                67.0        0.0     17627.75      1.0
# 69                55.0        0.0      6639.50      1.0
# 125              106.0        1.0      5822.25      1.0
# ...                ...        ...          ...      ...
# 21551              6.0        0.0      5526.25      1.0
# 21568              6.0        0.0      4155.75      1.0
# 21590             13.0        0.0      4816.00      1.0
# 21597             13.0        0.0      4236.25      1.0
# 21600             12.0        0.0      4257.00      1.0
#
# [947 rows x 11 columns]

# %% [markdown]
# **NOVO CLUSTER PARA ESCOLHER QUAL VENDER MAIS RÁPIDO**

# %%
a=pd.DataFrame(dem2['Tempoconstruido'].values)
a = np.array(a)
b=pd.DataFrame(dem2['v_med_mquad'].values)
b = np.array(b)
x1= np.concatenate((a,b), axis = 1)
x1
# Out:
# array([[1.900000e+01, 2.819250e+04],
#        [5.200000e+01, 1.274175e+04],
#        [6.700000e+01, 1.762775e+04],
#        ...,
#        [1.300000e+01, 4.816000e+03],
#        [1.300000e+01, 4.236250e+03],
#        [1.200000e+01, 4.257000e+03]])

# %% [markdown]
# **LEVANDO COMO BASE A OBTENÇÃO DOS IMÓVEIS DO AGRUPAMENTO 2 PELA EMPRESA PARA REVENDA.**
#
# **FILTRANDO QUANTOS IMOVEIS TEM MENOS DE 20 ANOS DE CONSTRUÍDO. PARA ASSIM INDICAR QUAIS IMÓVEIS TEM ALTA OU BAIXA CHANCE DE SAÍDA.**

# %%
from sklearn.cluster import KMeans
wcss1 = []
for i in range(1, 11):
    kmeans1 = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans1.fit(x1)
    wcss1.append(kmeans1.inertia_)
plt.plot(range(1, 11), wcss1)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans1 = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
y_kmeans1 = kmeans1.fit_predict(x1)

# %%
plt.scatter(x1[y_kmeans1 == 0, 0], x1[y_kmeans1 == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(x1[y_kmeans1 == 1, 0], x1[y_kmeans1 == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(x1[y_kmeans1 == 2, 0], x1[y_kmeans1 == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(kmeans1.cluster_centers_[:, 0], kmeans1.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Tempo de construido')
plt.ylabel('Metro Quadrado')
plt.legend()
plt.show()

# %% [markdown]
# **COM ISSO PODE SER VISTO QUE OS IMÓVEIS QUE TEM MAIS CHANCE DE SAÍDA PARA REVENDER SÃO DO AGRUPAMENTO 3 DEPOIS 1 E POR FIM 2, POIS LEVANDO COMO BASE OS IMÓVEIS COM MENOS TEMPO DE CONSTRUÍDO E COM VALOR DE METRO QUADRADO ELEVADO, ESSES IMÓVEIS, SÃO OS MELHORES PARA RETIRAR UM EXCELENTE LUCRO, POIS SÃO IMÓVEIS RELATIVAMENTE NOVOS E QUE PODEM SER COMPRADO POR UM ÓTIMO CUSTO BENEFÍCIOS, E POR TER UM VALOR DE METRO QUADRADO ELEVADO, ISSO INDICA QUE É UM IMOVEL CONSTRUÍDO EM UM LOCAL ALTAMENTE VALORIZADO E PROCURADO PELOS CLIENTES.**

# %%
vf1 = dem2.values
vfpr1=pd.DataFrame(y_kmeans1)
vfpr = np.array(vfpr1)
vdf = np.concatenate((vf1,vfpr), axis = 1)
vdf
# Out:
# array([[1.225000e+06, 4.000000e+00, 4.500000e+00, ..., 2.819250e+04,
#         1.000000e+00, 1.000000e+00],
#        [2.000000e+06, 3.000000e+00, 2.750000e+00, ..., 1.274175e+04,
#         1.000000e+00, 1.000000e+00],
#        [1.350000e+06, 3.000000e+00, 2.500000e+00, ..., 1.762775e+04,
#         1.000000e+00, 1.000000e+00],
#        ...,
#        [1.222500e+06, 4.000000e+00, 3.500000e+00, ..., 4.816000e+03,
#         1.000000e+00, 1.000000e+00],
#        [1.575000e+06, 4.000000e+00, 3.250000e+00, ..., 4.236250e+03,
#         1.000000e+00, 1.000000e+00],
#        [1.537000e+06, 5.000000e+00, 3.750000e+00, ..., 4.257000e+03,
#         1.000000e+00, 1.000000e+00]])

# %%
vftrr= pd.DataFrame(vdf)
vfinal = vftrr.rename({0:'Valor',1:'Quartos',2:'Banheiros',3:'Andares',4:'Aguafrente',5:'vista',6:'Condições',7:'Tempoconstruido',8:'Reformado',9:'v_med_mquad',10:'Padrões',11:'Padrao de vendas'}, axis=1)
vfinal
# Out:
#          Valor  Quartos  Banheiros  Andares  Aguafrente  vista  Condições  \
# 0    1225000.0      4.0       4.50      1.0         0.0    0.0        3.0
# 1    2000000.0      3.0       2.75      1.0         0.0    4.0        3.0
# 2    1350000.0      3.0       2.50      1.0         1.0    2.0        5.0
# 3    1325000.0      5.0       2.25      1.0         0.0    0.0        3.0
# 4    1450000.0      4.0       2.75      1.5         0.0    0.0        3.0
# ..         ...      ...        ...      ...         ...    ...        ...
# 942  1375000.0      5.0       4.50      2.0         0.0    0.0        3.0
# 943  1700000.0      4.0       3.50      2.0         0.0    0.0        3.0
# 944  1222500.0      4.0       3.50      1.5         0.0    0.0        3.0
# 945  1575000.0      4.0       3.25      2.0         0.0    0.0        3.0
# 946  1537000.0      5.0       3.75      2.0         0.0    0.0        3.0
#
#      Tempoconstruido  Reformado  v_med_mquad  Padrões  Padrao de vendas
# 0               19.0        0.0     28192.50      1.0               1.0
# 1               52.0        0.0     12741.75      1.0               1.0
# 2               67.0        0.0     17627.75      1.0               1.0
# 3               55.0        0.0      6639.50      1.0               1.0
# 4              106.0        1.0      5822.25      1.0               1.0
# ..               ...        ...          ...      ...               ...
# 942              6.0        0.0      5526.25      1.0               1.0
# 943              6.0        0.0      4155.75      1.0               1.0
# 944             13.0        0.0      4816.00      1.0               1.0
# 945             13.0        0.0      4236.25      1.0               1.0
# 946             12.0        0.0      4257.00      1.0               1.0
#
# [947 rows x 12 columns]

# %% [markdown]
# **PRIMEIRO A VENDER**
#
# **LISTEI OS 5 MELHORES LEVANDO BASE O VALOR DO METRO QUADRADO**

# %%
pvendas3= vfinal.loc[vfinal['Padrao de vendas']==2]
pvendas3.nlargest(n=3,columns='v_med_mquad')
# Out:
#          Valor  Quartos  Banheiros  Andares  Aguafrente  vista  Condições  \
# 266  1998000.0      2.0       2.50      2.0         0.0    0.0        3.0
# 284  1650000.0      4.0       3.25      3.0         0.0    3.0        3.0
# 886  1600000.0      4.0       5.50      2.0         0.0    2.0        3.0
#
#      Tempoconstruido  Reformado  v_med_mquad  Padrões  Padrao de vendas
# 266             11.0        0.0    232055.75      1.0               2.0
# 284             18.0        0.0    222373.50      1.0               2.0
# 886             12.0        0.0    221065.00      1.0               2.0

# %% [markdown]
# **SEGUNDO A VENDER**
#
# **LISTEI OS 5 MELHORES LEVANDO BASE O VALOR DO METRO QUADRADO**

# %%
pvendas1= vfinal.loc[vfinal['Padrao de vendas']==0]
pvendas1.nlargest(n=5,columns='v_med_mquad')
# Out:
#          Valor  Quartos  Banheiros  Andares  Aguafrente  vista  Condições  \
# 346  2140000.0      4.0       3.75      2.0         0.0    3.0        3.0
# 431  1700000.0      4.0       3.50      2.0         0.0    0.0        3.0
# 430  1565000.0      4.0       3.50      2.0         0.0    0.0        3.0
# 779  1862000.0      4.0       5.25      2.0         0.0    2.0        3.0
# 136  1290000.0      5.0       3.50      1.0         0.0    0.0        3.0
#
#      Tempoconstruido  Reformado  v_med_mquad  Padrões  Padrao de vendas
# 346             23.0        0.0    116048.75      1.0               0.0
# 431             14.0        0.0     86105.75      1.0               0.0
# 430             18.0        0.0     83488.75      1.0               0.0
# 779             14.0        0.0     82849.25      1.0               0.0
# 136             18.0        0.0     74790.00      1.0               0.0

# %% [markdown]
# **VALE RESSALTAR QUE MESMO QUE ESSES IMÓVEIS ABAIXO CLASSIFICADOS COMO ÚLTIMO A SEREM VENDIDOS, FICA A DISPOSIÇÃO DO CEO DA EMPRESA A OBTENÇÃO OU NÃO DELES PARA REVENDA, POIS MESMO TENDO UM EXCELENTE CUSTO BENEFÍCIO ENTRE "VALOR DE COMPRA X LUCRO", DEVIDO O EXCELENTE VALOR DO METRO QUADRADO, OS MESMOS SÃO IMOVEIS QUE NA SUA MÉDIA TEM MUITOS ANOS DE CONSTRUÍDO, OU SEJA SÃO RELATIVAMENTE ANTIGOS, LOGO MINHA SUGESTÃO É QUE DENTRE ESSES O MAIS INTERESSANTE É REALIZAR A OBTENÇÃO SOMENTE DOS QUE FORAM REFORMADOS. LOGO ABAIXO IREI LISTA-LOS.**

# %% [markdown]
# **TERCEIRO A VENDER**
#
# **LISTEI OS 5 MELHORES LEVANDO BASE O VALOR DO METRO QUADRADO**

# %%
pvendas2= vfinal.loc[vfinal['Padrao de vendas']==1]
pvendas2.nlargest(n=5,columns='v_med_mquad')
# Out:
#          Valor  Quartos  Banheiros  Andares  Aguafrente  vista  Condições  \
# 207  1525000.0      4.0       3.50      2.0         0.0    0.0        3.0
# 271  1900000.0      4.0       3.25      2.0         0.0    0.0        3.0
# 836  1360000.0      4.0       3.00      2.0         0.0    0.0        4.0
# 939  1450000.0      4.0       3.50      2.0         0.0    0.0        3.0
# 0    1225000.0      4.0       4.50      1.0         0.0    0.0        3.0
#
#      Tempoconstruido  Reformado  v_med_mquad  Padrões  Padrao de vendas
# 207             16.0        0.0     30764.50      1.0               1.0
# 271             42.0        0.0     30195.25      1.0               1.0
# 836             33.0        0.0     29940.00      1.0               1.0
# 939              6.0        0.0     29366.25      1.0               1.0
# 0               19.0        0.0     28192.50      1.0               1.0

# %% [markdown]
# **SEGUE ABAIXO OS IMÓVEIS A SEREM VENDIDOS POR ÚLTIMO, QUE FORAM REFORMADOS.**
#
# **LISTEI OS 5 MELHORES LEVANDO BASE O VALOR DO METRO QUADRADO**

# %%
preform = pvendas2.loc[pvendas2['Reformado']==1]
preform.nlargest(n = 5, columns= 'v_med_mquad')
# Out:
#          Valor  Quartos  Banheiros  Andares  Aguafrente  vista  Condições  \
# 483  1580000.0      4.0       2.50      2.0         0.0    4.0        5.0
# 176  1150000.0      3.0       2.75      2.0         1.0    4.0        3.0
# 797  1225000.0      4.0       2.50      2.0         1.0    4.0        4.0
# 385  1350000.0      5.0       3.00      1.5         0.0    2.0        3.0
# 158  1379900.0      3.0       3.25      1.0         1.0    4.0        3.0
#
#      Tempoconstruido  Reformado  v_med_mquad  Padrões  Padrao de vendas
# 483             72.0        1.0     20906.75      1.0               1.0
# 176             95.0        1.0     20587.25      1.0               1.0
# 797             46.0        1.0     13924.00      1.0               1.0
# 385             51.0        1.0     12469.00      1.0               1.0
# 158             42.0        1.0     11402.50      1.0               1.0
